# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib
import matplotlib.pyplot as plt 
plt.style.use('ggplot') 
from matplotlib.pyplot import figure 

# %matplotlib inline 
matplotlib.rcParams['figure.figsize'] = (12,8) # Adjusting the configuration of the plots that we will create

## Reading in the Data
df = pd.read_csv(r'C:\Users\Laingo\Documents\SQL\archive\movies.csv')

# %%
##Looking at the Data 
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
##Looking for Missing Data 
for col in df.columns: 
    pct_missing = np.mean(df[col].isnull()) 
    print('{} - {}%'.format(col, pct_missing))
# Out:
# name - 0.0%
# rating - 0.010041731872717789%
# genre - 0.0%
# year - 0.0%
# released - 0.0002608242044861763%
# score - 0.0003912363067292645%
# votes - 0.0003912363067292645%
# director - 0.0%
# writer - 0.0003912363067292645%
# star - 0.00013041210224308815%
# country - 0.0003912363067292645%
# budget - 0.2831246739697444%
# gross - 0.02464788732394366%
# company - 0.002217005738132499%
# runtime - 0.0005216484089723526%

# %%
df.dtypes
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
# Creating correct year column
df['correctyear'] = df['released'].astype(str).str[:4]
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
# ...

# %%
df.sort_values(by=['gross'], inplace=False, ascending=False)
df.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country      budget        gross  company  runtime  correctyear
# 0  1047       54  19000000.0   46998772.0     2319    146.0           14
# 1   327       55   4500000.0   58853106.0      731    104.0           13
# 2  1745       55  18000000.0  538375067.0     1540    124.0           14
# 3  2246       55   3500000.0   83453539.0     1812     88.0           13
# 4   410       55   6000000.0   39846344.0     1777     98.0           13

# %%
pd.set_option('display.max_rows', None)

# %%
# Removing duplcates from the data

df['company'].drop_duplicates().sort_values(ascending=False)
df.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  6587       6      6  1980      1705    8.4   927000.0      2589    4014
# 1  5573       6      1  1980      1492    5.8    65000.0      2269    1632
# 2  5142       4      0  1980      1771    8.7  1200000.0      1111    2567
# 3   286       4      4  1980      1492    7.7   221000.0      1301    2000
# 4  1027       6      4  1980      1543    7.3   108000.0      1054     521
#
#    star  country      budget        gross  company  runtime  correctyear
# 0  1047       54  19000000.0   46998772.0     2319    146.0           14
# 1   327       55   4500000.0   58853106.0      731    104.0           13
# 2  1745       55  18000000.0  538375067.0     1540    124.0           14
# 3  2246       55   3500000.0   83453539.0     1812     88.0           13
# 4   410       55   6000000.0   39846344.0     1777     98.0           13

# %%
#Scatter plot with budget vs gross
plt.scatter(x=df['budget'], y=df['gross'])
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')
plt.show()

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# Plotting budget vs Gross using Seaborn 

sns.regplot(x='budget', y='gross', data=df, scatter_kws={"color": "red"}, line_kws={"color": "blue"})
# Out:
# <AxesSubplot:xlabel='budget', ylabel='gross'>

# %%
# Correlation Pearson method is default

df.corr()
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.097995  0.222945  0.329321  0.257486  0.120811
# score    0.097995  1.000000  0.409182  0.076254  0.186258  0.399451
# votes    0.222945  0.409182  1.000000  0.442429  0.630757  0.309212
# budget   0.329321  0.076254  0.442429  1.000000  0.740395  0.320447
# gross    0.257486  0.186258  0.630757  0.740395  1.000000  0.245216
# runtime  0.120811  0.399451  0.309212  0.320447  0.245216  1.000000

# %%
df.corr(method='kendall')
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.067652  0.331465  0.224120  0.200618  0.097184
# score    0.067652  1.000000  0.300115 -0.000566  0.086046  0.283611
# votes    0.331465  0.300115  1.000000  0.353702  0.548899  0.198240
# budget   0.224120 -0.000566  0.353702  1.000000  0.512637  0.235483
# gross    0.200618  0.086046  0.548899  0.512637  1.000000  0.168933
# runtime  0.097184  0.283611  0.198240  0.235483  0.168933  1.000000

# %%
#Noted: There is a high correlation between budget and gross
# Visualizing the correlation

correlation_matrix = df.corr(method='pearson')
sns.heatmap(correlation_matrix, annot=True)

plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
#Analysing Company data
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df_numerized = df

# %%
for col_name in df_numerized.columns:
   if(df_numerized[col_name].dtype == 'object'):
    df_numerized[col_name] = df_numerized[col_name].astype('category')
    df_numerized[col_name] = df_numerized[col_name].cat.codes

# %%
   
dv = df_numerized
dv
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.008069  0.016355  0.011453 -0.011311  0.017097
# rating      -0.008069  1.000000  0.072423  0.008779  0.016613 -0.001314
# genre        0.016355  0.072423  1.000000 -0.081261  0.029822  0.027965
# year         0.011453  0.008779 -0.081261  1.000000 -0.000695  0.097995
# released    -0.011311  0.016613  0.029822 -0.000695  1.000000  0.042788
# score        0.017097 -0.001314  0.027965  0.097995  0.042788  1.000000
# votes        0.013088  0.033225 -0.145307  0.222945  0.016097  0.409182
# director     0.009079  0.019483 -0.015258 -0.020795 -0.001478  0.009559
# writer       0.009081 -0.005921  0.006567 -0.008656 -0.002404  0.019416
# star         0.006472  0.013405 -0.005477 -0.027242  0.015777 -0.001609
# country     -0.010737  0.081244 -0.037615 -0.070938 -0.020427 -0.133348
# budget       0.023970 -0.176002 -0.356564  0.329321  0.014683  0.076254
# ...

# %%
# Visualizing df_numerized

df_numerized = df.corr(method='pearson')
sns.heatmap(df_numerized, annot=True)

plt.title('Correlation Matrix for Numeric Features')
plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
dv.corr()
# Out:
#                  name    rating     genre      year  released     score  \
# name         1.000000 -0.090602  0.005657 -0.088550 -0.138085 -0.099397
# rating      -0.090602  1.000000  0.191883 -0.173772 -0.063581 -0.133409
# genre        0.005657  0.191883  1.000000 -0.345602  0.041330 -0.104050
# year        -0.088550 -0.173772 -0.345602  1.000000 -0.170255  0.153495
# released    -0.138085 -0.063581  0.041330 -0.170255  1.000000 -0.107455
# score       -0.099397 -0.133409 -0.104050  0.153495 -0.107455  1.000000
# votes       -0.146665 -0.225862 -0.518501  0.403787 -0.225127  0.554937
# director    -0.075280 -0.041598 -0.031690 -0.200941 -0.138512 -0.155675
# writer      -0.071065 -0.075706  0.012066 -0.187599 -0.135665 -0.141208
# star        -0.063666 -0.036720 -0.008955 -0.185909 -0.071555 -0.149649
# country     -0.097030  0.069495 -0.122072 -0.217647 -0.155337 -0.381044
# budget      -0.090029 -0.440852 -0.718472  0.533730 -0.172078  0.189184
# ...

# %%
correlation_mat = df_numerized.corr()
corr_pairs = correlation_mat.unstack()
corr_pairs
# Out:
# name         name           1.000000
#              rating        -0.090602
#              genre          0.005657
#              year          -0.088550
#              released      -0.138085
#              score         -0.099397
#              votes         -0.146665
#              director      -0.075280
#              writer        -0.071065
#              star          -0.063666
#              country       -0.097030
#              budget        -0.090029
#              gross         -0.126160
#              company       -0.082476
#              runtime       -0.120596
#              correctyear   -0.138005
# rating       name          -0.090602
#              rating         1.000000
#              genre          0.191883
#              year          -0.173772
#              released      -0.063581
#              score         -0.133409
#              votes         -0.225862
#              director      -0.041598
#              writer        -0.075706
# ...

# %%
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# genre        budget        -0.718472
# budget       genre         -0.718472
# genre        gross         -0.636524
# gross        genre         -0.636524
# votes        genre         -0.518501
# genre        votes         -0.518501
# budget       rating        -0.440852
# rating       budget        -0.440852
# gross        rating        -0.389179
# rating       gross         -0.389179
# country      score         -0.381044
# score        country       -0.381044
# year         genre         -0.345602
# genre        year          -0.345602
#              runtime       -0.297181
# runtime      genre         -0.297181
#              country       -0.289845
# country      runtime       -0.289845
# company      genre         -0.263137
# genre        company       -0.263137
# gross        writer        -0.245964
# writer       gross         -0.245964
#              votes         -0.243208
# votes        writer        -0.243208
# writer       budget        -0.237882
# ...

# %%
high_corr = sorted_pairs[(sorted_pairs) > 0.5]
high_corr
# Out:
# runtime      votes          0.533638
# votes        runtime        0.533638
# year         budget         0.533730
# budget       year           0.533730
# votes        score          0.554937
# score        votes          0.554937
# runtime      score          0.629251
# score        runtime        0.629251
# budget       votes          0.736469
# votes        budget         0.736469
# gross        votes          0.857553
# votes        gross          0.857553
# budget       gross          0.939127
# gross        budget         0.939127
# released     correctyear    0.999970
# correctyear  released       0.999970
# name         name           1.000000
# company      company        1.000000
# gross        gross          1.000000
# budget       budget         1.000000
# country      country        1.000000
# star         star           1.000000
# writer       writer         1.000000
# director     director       1.000000
# votes        votes          1.000000
# ...

# %%
# Votes and budget have highest correlation to gross earnings
#Final Analysis: Company has Low Correlation
